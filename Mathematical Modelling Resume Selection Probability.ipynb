# %% [markdown]
# # Model Explaining The Chance Of My Resume Selection

# %% [markdown]
# ## Equation Image Form
# <br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <br>

# %% [markdown]
# ## Equation Written Form
# <br>
#
# $$
# f(x) = \text{coefficient} \times \left( \text{stats} \times (1 + \text{prob}) + \text{prob} + \text{financial accounting} \times (1 + \text{statements analysis}) \right. \\
# \left. + \text{Cash flow Valuation} + \text{Finance Models} + \text{Microeconomics} + \text{Macroeconomics}\right. \\
# \left. + \text{Calculus} \times (1 + \text{Nonlinear Optimization}) + \text{Linear Algebra} + \text{Linear Programming} \right. \\
# \left. + \text{PowerBI} + \text{Excel} + \text{Tableau} + \text{Python} \times (1 + \text{Pandas} \times \text{Jupyter} \times \text{Numpy} \times \text{Matplotlib} + \text{Seaborn}) \right. \\
# \left. + (\text{Data Analysis} \times \text{Time Series Analysis} \times (1 + \text{Feature Engineering}) )+ \text{SQL} + R(1 + \text{Tidyverse}) + \text{Java}(1 + \text{OOP}) + \text{OOP} \right)
# $$

# %% [markdown]
# $$
# \text{coefficient} = \text{macroeconomic outlook coefficient} \times \text{ug university coefficient} \times \text{degree percentage coefficient} \times \text{portfolio projects coefficient}
# $$

# %% [markdown]
# ## Model Explanation
#
# 1. The model is based on the famous Logistic Model.
# 2. $x$ is the vector of variables
#
# - all the 4 coefficients in our equation range around 1.
#     - as the current macroeconomic outlook for India is positive and getting better by months and years, this coefficient should be more than 1 such as 1.1 or 1.25.
#     - as my ug degree is not a particularly reputated one, the coefficient could be 0.8
#     - as my percentages in ug degree is 66 let the coefficient be 0.66 for simplicity
#     - for the coefficient of portfolio projects, a survey and data collection would be required to assess the level of portfolio projects a typical candidate presents, so I wouldn't comment much on this, but it still ranges around 1
#
# <br>
#
# - the variables here should measure expertise in that subject, so its domain can be between 1 and 10 or we can take it as any real number, if we take an ordinal perspective, assuming a higher with higher skills but no measure of how much higher, just simply higher
# - many variables have correlations with each other and many of them can also exist independent of others
#     - for instance in our first pair of correlated variables we have stats and prob, where some stats can be known without knowing prob and prob can also be known without stats but if one knows them together then they both complement each other, therefore, in our model stats increases further if prob increases and prob also increases on its own without any knowledge of stats
#     - many variables are modelled in the same way as explained in the previous line
#     - data analysis and related skills have correlation with Python, R, Jupyter, SQL, PowerBI, Excel, Tableau and other things,but for simplicty I have assumed in the model that it has no correlation with other variables except for Time Series Analysis and Feature Engineering
# - Java is mostly used for OOP related work, so we assume in the model that OOP has correlation only with Java and not with Python
# - OOP also has its own marginal contribution
# - for the same thing, Calculus has its own marginal contribution, but you can't know nonlinear optimization without knowing Calculus, so in our model knowledge of nonlinear optimization increases Calculus's contribution but when calculus is zero the other is already zero
#
# **As there are dozens of variables explaining each one would be a clutter, so I have given a broader overview of the model**
#
# - For a general overview, there are only three kinds of variables:
#     - ones having only their own marginal contribution
#     - ones having correlation with other variables and their own marginal contribution
#     - ones having correlation with other variables and no contribution of their own without the other variables that they correlate with.
#
# **Working of the model**
#
# - Variables that increases the skillset increases the probability towards 1.
# - Variables that decrease the skillsest or coefficients that scale down the skillset decreases the probability.
#
# **If someone is interested in understanding the model further, I can explain, but in written form explaining further is cumbersome.**
